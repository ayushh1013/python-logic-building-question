# %%
### topic

# %%
## key feature python
 - ree and open source
- Object-oriented programming
- GUI programming support
- High-level programming language
- Language interpretation
- Standard library
- cross platform
- Dynamically typed
- Easy to learn

# %%
for i in range(9):
 print("* *")
# Out:
# ** /n *
# ** /n *
# ** /n *
# ** /n *
# ** /n *
# ** /n *
# ** /n *
# ** /n *
# ** /n *

# %%
a = int(input())
b= int(input())
print('sum of a and b is', a + b)
# Out:
#  9
#  8
# sum of a and b is 17

# %%
# to find square root of a number
#num = 64
num1 = int(input ())
sr = num1**0.5
print('the square of th gibve number is',sr)
# Out:
#  89
# the square of th gibve number is 9.433981132056603

# %%
#using math module
import math
num = int(input())
sr = math.sqrt(num)
print(sr)
# Out:
#  49
# 7.0

# %%
# to find area of tringle
height = float(input())
base = float(input())
area= (1/2)*base*height
print(area)
# Out:
#  23.3
#  34
# 396.1

# %%
# swap the numbers using temp
x = 13
y = 12

temp = x
x = y
y = temp
print(x,y)
# Out:
# 12 13

# %%
#solution2(without using third variable)
x = 12
y = 13
x,y = y,x
print(x,y)
# Out:
# 13 12

# %%
# converrt kilometer to mile
km = float(input())
miles = (0.621371)*km
print(miles)
# Out:
#  5
# 3.106855

# %%
#Program to check if a number is positive, negative or zero
num = 0
if num > 0:
    print('positive')
elif num == 0:
    print('Zero')

else:
    print('negative')
# Out:
# Zero

# %%
#check odd or even
num = 2
if num % 2 == 0:
    print("even",num)
else:
    print("odd",num)
# Out:
# even 2

# %%
# to find a leap year
year  = int(input())
if (year % 400 == 0) and (year % 100 == 0):
    print(year,"is a leap year")

elif (year % 4 == 0) and (year %  100 != 0):
    print(year, "is leap year")

else:
    print(year,"is not a leap year")
# Out:
#  2024
# 2024 is leap year

# %%
#find largest no 
num  = 23
num2 = 334
num3 = 8904
if num > num2 and num > num3:
   print("num is greater")
elif num2 > num and num2 > num3:
    print("num 2 is greater")

else: 
    print("num3 is greater")
# Out:
# num3 is greater

# %%
# prime no
num = 90
if num == 1:
    print("np")
if num >1:
   for i in range(2,num):
      if num % i == 0:
          print("np")
          break
   else:
        print("P")
# Out:
# np

# %%
import random

# %%
num = random.randint(1,6)

# %%
num
# Out:
# 2

# %%
# Count words Frequency in sentence
sent = "python is easy and python is powerful"
word=sent.split()
print(word)
dict={}
for w in word:
     if w in dict:
         dict[w] +=1
     else:
         dict[w]=1     

print(dict)
# Out:
# ['python', 'is', 'easy', 'and', 'python', 'is', 'powerful']
# {'python': 2, 'is': 2, 'easy': 1, 'and': 1, 'powerful': 1}

# %%
#function
def square(x):
    return x*x

number = [1,2,3,4]
result = map(square,number)
print(list (result))
# Out:
# [1, 4, 9, 16]

# %%
n = [3,3]
print(square,n)
# Out:
# <function square at 0x00000210921DB2E0> [3, 3]

# %%
#Create a separate dictionary for
#product with price greater than 20.
prod = {"prod":10,"Book":50,"Bag":400,"pencil":5}
new_prod = {n:v for n,v in prod.items() if v>20}
print(new_prod)
# Out:
# {'Book': 50, 'Bag': 400}

# %%
# table 
n = 4
for i in range(1,11):
    print(n,"x",i,"=",n*i)
# Out:
# 4 x 1 = 4
# 4 x 2 = 8
# 4 x 3 = 12
# 4 x 4 = 16
# 4 x 5 = 20
# 4 x 6 = 24
# 4 x 7 = 28
# 4 x 8 = 32
# 4 x 9 = 36
# 4 x 10 = 40

# %%
#using while loop
n = 5
i = 1
while i<=10:
    print(n,"x",i,"=",n*i)
    i += 1
# Out:
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50

# %%
#fibonacci serires
a = 0
b = 1
num =7
if num ==1:
    print(a)

else:
    print(a)
    print(b)
    for i in range(1,num+1):
        c = a + b
        a = b
        b = c
        print(c, end=" ")
# Out:
# 0
# 1
# 1 2 3 5 8 13 21

# %%
for i in range(1,6):
   print(i, end=" ")
# Out:
# 1 2 3 4 5

# %%
for i in range(1,6):
    print(i ** 2 , end=" ")
# Out:
# 1 4 9 16 25

# %%
for i in range(1,11):
    if i % 2 == 0:
        print(i, end=" ")
# Out:
# 2 4 6 8 10

# %%
total = 0
for i in range(1,11):
    total += i

print(f' sum is {total}')
# Out:
#  sum is 55

# %%
word = 'Drishti'
for i in range(len(word) -1,-1,-1):
    print(word[i],end=" ")
# Out:
# i t h s i r D

# %%
vowels = "aeiou"
word = "Drishti ayush"
count = 0
for char in word:
    if char in vowels:
        count += 1

print(f' total {word} is {count}')
# Out:
#  total Drishti ayush is 4

# %%
#armstrong
num = int(input())
sum = 0
temp = num
while temp > 0:
    digit = temp%10
    cube = digit ** 3
    sum = sum + cube
     temp //=  10

if sum == num:
    print("it is an armstrong number")
else:
    print("tmkc")

# %%
#power 2
nterms = int(input())
result = list(map(lambda x:3 ** x, range(nterms+1)))
for i in range (nterms+1):
    print("the value of 2 raised to power",i,"is",result[i])
# Out:
#  3
# the value of 2 raised to power 0 is 1
# the value of 2 raised to power 1 is 3
# the value of 2 raised to power 2 is 9
# the value of 2 raised to power 3 is 27

# %%
import random,itertools

# %%
deck = list(itertools.product(range(1,14),['spade','club','heart','diamond']) )
random.shuffle(deck)
print(deck)
for i in range(5):
    print(deck[i][0], "of", deck[i][1])
# Out:
# [(5, 'heart'), (12, 'heart'), (5, 'diamond'), (7, 'heart'), (8, 'diamond'), (5, 'spade'), (10, 'diamond'), (6, 'heart'), (1, 'diamond'), (5, 'club'), (13, 'spade'), (2, 'spade'), (9, 'diamond'), (13, 'club'), (4, 'diamond'), (11, 'diamond'), (12, 'spade'), (3, 'heart'), (6, 'spade'), (4, 'heart'), (3, 'diamond'), (7, 'diamond'), (1, 'heart'), (10, 'heart'), (8, 'spade'), (8, 'club'), (13, 'heart'), (8, 'heart'), (11, 'heart'), (2, 'club'), (2, 'diamond'), (9, 'club'), (12, 'diamond'), (12, 'club'), (13, 'diamond'), (4, 'club'), (7, 'spade'), (10, 'club'), (6, 'diamond'), (11, 'spade'), (7, 'club'), (1, 'spade'), (9, 'spade'), (2, 'heart'), (6, 'club'), (1, 'club'), (4, 'spade'), (3, 'club'), (9, 'heart'), (3, 'spade'), (10, 'spade'), (11, 'club')]
# 5 of heart
# 12 of heart
# 5 of diamond
# 7 of heart
# 8 of diamond

# %%
cities = ["Berlin","Rome","Madrid"]
print(max(cities))
# Out:
# Rome

# %%
#Solution 1 using For Loop
print("The numbers divisible by 13 are: ")

for i in range (1,100):
    if i % 13 == 0:
        print(i)
# Out:
# The numbers divisible by 13 are:
# 13
# 26
# 39
# 52
# 65
# 78
# 91

# %%
#using lambda function
l = [39,48,26,98,33,67,87]

result = list(filter(lambda x : x % 13 == 0 ,l))

# %%
print(result)
# Out:
# [39, 26]
